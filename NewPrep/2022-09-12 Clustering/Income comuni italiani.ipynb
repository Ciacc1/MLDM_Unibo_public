# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Variables
file_name= 'income.csv'
random_state = 42

np.random.seed(random_state)

df= pd.read_csv(file_name)
df.head()
# Out:
#    Unnamed: 0             Territorio  NC_   -  0  NC_  0- 10  ...  NC_ 55- 75  NC_ 75-120  NC_120-inf   Income_tot
# 0           0            Abano Terme         0.0      3641.0  ...       413.0       400.0       177.0  347774542.0
# 1           1        Abbadia Cerreto         0.0        50.0  ...         0.0         0.0         0.0    3399810.0
# 2           2        Abbadia Lariana         0.0       511.0  ...        78.0        48.0        31.0   59153455.0
# 3           3  Abbadia San Salvatore         0.0      1303.0  ...        69.0        33.0        13.0   87615654.0
# 4           4              Abbasanta         0.0       577.0  ...        26.0        13.0         0.0   30992769.0
#
# [5 rows x 11 columns]
